# %% [markdown]
# I have chosen TMDb movie data. This dataset contains information about 5000 movies. Columns like genres,cast,crew are in dictionary format so before starting anything we have to clean them first.
#
# Here are the four questions I have decided to give answer:
#
# QUES1: How is moving average of 10 years is trending across top three categories?
#
# QUES2: Which factor is maximum positive impact on revenue?
#
# QUES3: Which movie has given maximum hit for each year?
#
# QUES4: Which actor has given maximum hit in each year?

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df_credit = pd.read_csv(r'C:\Users\pierc\Downloads\tmdb-5000-movie-dataset\tmdb_5000_credits.csv',parse_dates=True)
df_movie = pd.read_csv(r'C:\Users\pierc\Downloads\tmdb-5000-movie-dataset\tmdb_5000_movies.csv',parse_dates=True)

# %%
# Since genres is given in dictionary format, we have to extract first value from each genres
df_movie.genres = df_movie.genres.str.split(",",n=2,expand=True)[1]
df_movie.genres
# Out:
# 0                 "name": "Action"}
# 1              "name": "Adventure"}
# 2                 "name": "Action"}
# 3                 "name": "Action"}
# 4                 "name": "Action"}
# 5                "name": "Fantasy"}
# 6              "name": "Animation"}
# 7                 "name": "Action"}
# 8              "name": "Adventure"}
# 9                 "name": "Action"}
# 10             "name": "Adventure"}
# 11             "name": "Adventure"}
# 12             "name": "Adventure"}
# 13                "name": "Action"}
# 14                "name": "Action"}
# 15             "name": "Adventure"}
# 16       "name": "Science Fiction"}
# 17             "name": "Adventure"}
# 18                "name": "Action"}
# 19                "name": "Action"}
# 20                "name": "Action"}
# 21                "name": "Action"}
# 22             "name": "Adventure"}
# 23             "name": "Adventure"}
# 24             "name": "Adventure"}
# 25                 "name": "Drama"}
# 26             "name": "Adventure"}
# 27              "name": "Thriller"}
# 28                "name": "Action"}
# 29                "name": "Action"}
#                    ...
# 4773             "name": "Comedy"}]
# 4774               "name": "Drama"}
# 4775               "name": "Drama"}
# 4776              "name": "Comedy"}
# 4777              "name": "Drama"}]
# 4778              "name": "Action"}
# 4779             "name": "Comedy"}]
# 4780            "name": "Thriller"}
# 4781              "name": "Comedy"}
# 4782               "name": "Drama"}
# 4783            "name": "Thriller"}
# 4784               "name": "Drama"}
# 4785              "name": "Drama"}]
# 4786              "name": "Comedy"}
# 4787     "name": "Science Fiction"}
# 4788              "name": "Horror"}
# 4789              "name": "Drama"}]
# 4790               "name": "Drama"}
# 4791             "name": "Horror"}]
# 4792               "name": "Crime"}
# 4793              "name": "Drama"}]
# 4794            "name": "Thriller"}
# 4795              "name": "Drama"}]
# 4796     "name": "Science Fiction"}
# 4797             "name": "Foreign"}
# 4798              "name": "Action"}
# 4799              "name": "Comedy"}
# 4800              "name": "Comedy"}
# 4801                           None
# 4802        "name": "Documentary"}]
# Name: genres, Length: 4803, dtype: object

# %%
# Check for any nulls after splitting it:
df_movie.genres.isnull().sum()
# Out:
# 28

# %%
df_movie.genres.dropna(inplace=True)

# %%
# Confirm all nulls are filled with 0
df_movie.genres.isnull().sum()
# Out:
# 0

# %%
df_movie['genres'] = df_movie['genres'].apply(lambda x: x.split('"name"')[1])

# %%
df_movie['genres']
# Out:
# 0                : "Action"}
# 1             : "Adventure"}
# 2                : "Action"}
# 3                : "Action"}
# 4                : "Action"}
# 5               : "Fantasy"}
# 6             : "Animation"}
# 7                : "Action"}
# 8             : "Adventure"}
# 9                : "Action"}
# 10            : "Adventure"}
# 11            : "Adventure"}
# 12            : "Adventure"}
# 13               : "Action"}
# 14               : "Action"}
# 15            : "Adventure"}
# 16      : "Science Fiction"}
# 17            : "Adventure"}
# 18               : "Action"}
# 19               : "Action"}
# 20               : "Action"}
# 21               : "Action"}
# 22            : "Adventure"}
# 23            : "Adventure"}
# 24            : "Adventure"}
# 25                : "Drama"}
# 26            : "Adventure"}
# 27             : "Thriller"}
# 28               : "Action"}
# 29               : "Action"}
#                 ...
# 4773            : "Comedy"}]
# 4774              : "Drama"}
# 4775              : "Drama"}
# 4776             : "Comedy"}
# 4777             : "Drama"}]
# 4778             : "Action"}
# 4779            : "Comedy"}]
# 4780           : "Thriller"}
# 4781             : "Comedy"}
# 4782              : "Drama"}
# 4783           : "Thriller"}
# 4784              : "Drama"}
# 4785             : "Drama"}]
# 4786             : "Comedy"}
# 4787    : "Science Fiction"}
# 4788             : "Horror"}
# 4789             : "Drama"}]
# 4790              : "Drama"}
# 4791            : "Horror"}]
# 4792              : "Crime"}
# 4793             : "Drama"}]
# 4794           : "Thriller"}
# 4795             : "Drama"}]
# 4796    : "Science Fiction"}
# 4797            : "Foreign"}
# 4798             : "Action"}
# 4799             : "Comedy"}
# 4800             : "Comedy"}
# 4801                     NaN
# 4802       : "Documentary"}]
# Name: genres, Length: 4803, dtype: object

# %%
# Remove all special character from genres
df_movie['genres'] =  df_movie['genres'].str.replace('"', '')
df_movie['genres'] =  df_movie['genres'].str.replace(':', '')
df_movie['genres'] =  df_movie['genres'].str.replace(']', '')
df_movie['genres'] =  df_movie['genres'].str.replace('}', '')

# %%
# Remove white space from genres
df_movie['genres'] = df_movie['genres'].str.strip()

# %%
# Confirm all the values are proper
df_movie['genres']
# Out:
# 0                Action
# 1             Adventure
# 2                Action
# 3                Action
# 4                Action
# 5               Fantasy
# 6             Animation
# 7                Action
# 8             Adventure
# 9                Action
# 10            Adventure
# 11            Adventure
# 12            Adventure
# 13               Action
# 14               Action
# 15            Adventure
# 16      Science Fiction
# 17            Adventure
# 18               Action
# 19               Action
# 20               Action
# 21               Action
# 22            Adventure
# 23            Adventure
# 24            Adventure
# 25                Drama
# 26            Adventure
# 27             Thriller
# 28               Action
# 29               Action
#              ...
# 4773             Comedy
# 4774              Drama
# 4775              Drama
# 4776             Comedy
# 4777              Drama
# 4778             Action
# 4779             Comedy
# 4780           Thriller
# 4781             Comedy
# 4782              Drama
# 4783           Thriller
# 4784              Drama
# 4785              Drama
# 4786             Comedy
# 4787    Science Fiction
# 4788             Horror
# 4789              Drama
# 4790              Drama
# 4791             Horror
# 4792              Crime
# 4793              Drama
# 4794           Thriller
# 4795              Drama
# 4796    Science Fiction
# 4797            Foreign
# 4798             Action
# 4799             Comedy
# 4800             Comedy
# 4801                NaN
# 4802        Documentary
# Name: genres, Length: 4803, dtype: object

# %%
# Extract year from release date
df_movie['release_date'] = pd.to_datetime(df_movie['release_date'])

# %%
df_movie['year'] = df_movie['release_date'].dt.year

# %%
df_movie.year = df_movie.year.fillna(0).astype(int)

# %%
# Confirm that new column year has proper values
df_movie.year
# Out:
# 0       2009
# 1       2007
# 2       2015
# 3       2012
# 4       2012
# 5       2007
# 6       2010
# 7       2015
# 8       2009
# 9       2016
# 10      2006
# 11      2008
# 12      2006
# 13      2013
# 14      2013
# 15      2008
# 16      2012
# 17      2011
# 18      2012
# 19      2014
# 20      2012
# 21      2010
# 22      2013
# 23      2007
# 24      2005
# 25      1997
# 26      2016
# 27      2012
# 28      2015
# 29      2012
#         ...
# 4773    1994
# 4774    1971
# 4775    2002
# 4776    1997
# 4777    2002
# 4778    2009
# 4779    1990
# 4780    2015
# 4781    2013
# 4782    2003
# 4783    2015
# 4784    2005
# 4785    2014
# 4786    2009
# 4787    2011
# 4788    1972
# 4789    2004
# 4790    2000
# 4791    2007
# 4792    1997
# 4793    2004
# 4794    2012
# 4795    1995
# 4796    2004
# 4797    2005
# 4798    1992
# 4799    2011
# 4800    2013
# 4801    2012
# 4802    2005
# Name: year, Length: 4803, dtype: int32

# %%
# Highest top 3 categories 
df_movie.groupby('genres').revenue.sum().nlargest(3)
# Out:
# genres
# Action       91883487959
# Adventure    71515822443
# Drama        54752658561
# Name: revenue, dtype: int64

# %%
# For category- Action, plot the last 10 years moving average trend
df_action = df_movie.query('genres == "Action"').groupby('year').revenue.sum()
df_action = df_action.rolling(window=10).mean()
df_action
# Out:
# year
# 1930             NaN
# 1936             NaN
# 1947             NaN
# 1949             NaN
# 1950             NaN
# 1952             NaN
# 1954             NaN
# 1962             NaN
# 1963             NaN
# 1964    2.786066e+07
# 1966    2.826066e+07
# 1967    3.946554e+07
# 1969    4.006554e+07
# 1970    3.978554e+07
# 1971    4.585631e+07
# 1972    4.322631e+07
# 1973    4.408358e+07
# 1975    3.987358e+07
# 1976    2.398370e+07
# 1977    2.537570e+07
# 1978    5.492051e+07
# 1979    6.764841e+07
# 1980    8.644272e+07
# 1981    1.052578e+08
# 1982    1.219940e+08
# 1983    1.288357e+08
# 1984    1.757938e+08
# 1985    2.170214e+08
# 1986    2.617862e+08
# 1987    3.160091e+08
# 1988    3.234781e+08
# 1989    3.132950e+08
# 1990    3.708552e+08
# 1991    4.097992e+08
# 1992    4.226208e+08
# 1993    4.572336e+08
# 1994    5.559988e+08
# 1995    7.186971e+08
# 1996    9.550748e+08
# 1997    1.157348e+09
# 1998    1.299032e+09
# 1999    1.409027e+09
# 2000    1.537386e+09
# 2001    1.714052e+09
# 2002    1.938811e+09
# 2003    2.145657e+09
# 2004    2.373527e+09
# 2005    2.401985e+09
# 2006    2.325244e+09
# 2007    2.249296e+09
# 2008    2.346495e+09
# 2009    2.772384e+09
# 2010    2.966373e+09
# 2011    3.320908e+09
# 2012    3.682335e+09
# 2013    4.119966e+09
# 2014    4.435634e+09
# 2015    5.122604e+09
# 2016    5.595079e+09
# Name: revenue, dtype: float64

# %%
df_action.dropna(inplace=True)
plt.subplots(figsize=(10, 6))
plt.bar(df_action.index, df_action)
plt.title('10 Years moving average for category - Action')
plt.xlabel('Year')
plt.ylabel('Moving average');

# %%
# For category- Adventure, plot the last 10 years moving average trend
df_adventure = df_movie.query('genres == "Adventure"').groupby('year').revenue.sum()
df_adventure = df_adventure.rolling(window=10).mean()
df_adventure
# Out:
# year
# 1937             NaN
# 1939             NaN
# 1940             NaN
# 1953             NaN
# 1954             NaN
# 1956             NaN
# 1962             NaN
# 1963             NaN
# 1964             NaN
# 1965    5.381435e+07
# 1969    6.207567e+07
# 1970    6.060014e+07
# 1971    7.128490e+07
# 1972    7.078490e+07
# 1973    8.414268e+07
# 1974    9.285988e+07
# 1975    8.040324e+07
# 1976    7.730879e+07
# 1977    1.609044e+08
# 1978    1.488897e+08
# 1979    1.656582e+08
# 1980    2.175983e+08
# 1981    2.727503e+08
# 1982    2.806617e+08
# 1983    3.565039e+08
# 1984    3.900467e+08
# 1985    4.465494e+08
# 1986    4.774598e+08
# 1987    3.896500e+08
# 1988    4.153471e+08
# 1989    4.995996e+08
# 1990    5.387992e+08
# 1991    5.411801e+08
# 1992    5.654418e+08
# 1993    6.182077e+08
# 1994    5.958085e+08
# 1995    6.382118e+08
# 1996    6.618091e+08
# 1997    8.018636e+08
# 1998    8.721421e+08
# 1999    9.419319e+08
# 2000    1.034591e+09
# 2001    1.340988e+09
# 2002    1.632563e+09
# 2003    1.907422e+09
# 2004    2.221484e+09
# 2005    2.520617e+09
# 2006    2.837239e+09
# 2007    3.078547e+09
# 2008    3.417722e+09
# 2009    3.555747e+09
# 2010    3.668661e+09
# 2011    3.585084e+09
# 2012    3.634229e+09
# 2013    3.528093e+09
# 2014    3.474807e+09
# 2015    3.252542e+09
# 2016    3.070559e+09
# Name: revenue, dtype: float64

# %%
df_adventure .dropna(inplace=True)
plt.subplots(figsize=(10, 6))
plt.bar(df_adventure .index, df_adventure )
plt.title('10 Years moving average for category Adventure')
plt.xlabel('Year')
plt.ylabel('Moving average');

# %%
# For category- Drama, plot the last 10 years moving average trend
df_drama = df_movie.query('genres == "Drama"').groupby('year').revenue.sum()
df_drama = df_drama.rolling(window=10).mean()
df_drama
# Out:
# year
# 1916             NaN
# 1925             NaN
# 1927             NaN
# 1929             NaN
# 1932             NaN
# 1936             NaN
# 1938             NaN
# 1939             NaN
# 1940             NaN
# 1941    4.600797e+07
# 1942    4.621474e+07
# 1944    4.455104e+07
# 1945    4.719920e+07
# 1946    5.009281e+07
# 1947    5.087281e+07
# 1951    5.382281e+07
# 1953    5.702281e+07
# 1955    1.700516e+07
# 1956    1.874516e+07
# 1957    2.157516e+07
# 1958    2.228594e+07
# 1959    2.424964e+07
# 1960    2.577644e+07
# 1961    2.502703e+07
# 1962    2.517203e+07
# 1963    2.847203e+07
# 1964    3.349813e+07
# 1965    7.485273e+07
# 1966    7.534773e+07
# 1968    7.573949e+07
#             ...
# 1987    1.914615e+08
# 1988    2.323928e+08
# 1989    2.769976e+08
# 1990    2.814025e+08
# 1991    2.996901e+08
# 1992    3.402436e+08
# 1993    4.480735e+08
# 1994    4.598761e+08
# 1995    5.250560e+08
# 1996    6.097431e+08
# 1997    8.555406e+08
# 1998    9.603783e+08
# 1999    1.052915e+09
# 2000    1.209688e+09
# 2001    1.357863e+09
# 2002    1.571399e+09
# 2003    1.640425e+09
# 2004    1.870649e+09
# 2005    2.011550e+09
# 2006    2.163251e+09
# 2007    2.081071e+09
# 2008    2.272702e+09
# 2009    2.305637e+09
# 2010    2.437433e+09
# 2011    2.463966e+09
# 2012    2.468642e+09
# 2013    2.476767e+09
# 2014    2.383791e+09
# 2015    2.491346e+09
# 2016    2.277688e+09
# Name: revenue, Length: 78, dtype: float64

# %%
df_drama.dropna(inplace=True)
plt.subplots(figsize=(10, 6))
plt.bar(df_drama.index, df_drama)
plt.title('10 Years moving average for category Drama')
plt.xlabel('Year')
plt.ylabel('Moving average');

# %% [markdown]
# QUES1: How is moving average of 10 years is trending across top three categories?
#
# CONCLUSIONS : Action category is most promising and has upward trend, for adventure and drama category we can see that popularity of these two genres are decreasing.
#
#                                   **QUES1 ENDS**

# %%
df_movie.plot.scatter(x='revenue',y='budget');
df_movie.plot.scatter(x='revenue',y='popularity');
df_movie.plot.scatter(x='revenue',y='runtime');
df_movie.plot.scatter(x='revenue',y='vote_average');

# %% [markdown]
# QUES2: Which factor is maximum positive impact on revenue?
#
# CONCLUSION : After visualizing the scatter plots, we can see that all of the above four factors are not highly positively correleated with revenue.
#                                 **QUES2 ENDS**

# %%
# To analyse production companies, we have to first clean the dataset for production comapanies.
df_movie.production_companies = df_movie.production_companies.str.split(":",n=2,expand=True)[1]

# %%
df_movie['production_companies'] =df_movie['production_companies'].fillna(0)

# %%
df_movie['production_companies'] = df_movie['production_companies'].str.split(",",n=1,expand=True)[0]

# %%
df_movie['production_companies'] = df_movie['production_companies'].str.replace('"', '')
df_movie['production_companies'] = df_movie['production_companies'].str.strip()

# %%
# Confirm all changes done properly
df_movie['production_companies']
# Out:
# 0                    Ingenious Film Partners
# 1                       Walt Disney Pictures
# 2                          Columbia Pictures
# 3                         Legendary Pictures
# 4                       Walt Disney Pictures
# 5                          Columbia Pictures
# 6                       Walt Disney Pictures
# 7                             Marvel Studios
# 8                               Warner Bros.
# 9                                  DC Comics
# 10                                 DC Comics
# 11                           Eon Productions
# 12                      Walt Disney Pictures
# 13                      Walt Disney Pictures
# 14                        Legendary Pictures
# 15                               Walt Disney
# 16                        Paramount Pictures
# 17                      Walt Disney Pictures
# 18                      Amblin Entertainment
# 19                             WingNut Films
# 20                         Columbia Pictures
# 21                     Imagine Entertainment
# 22                             WingNut Films
# 23                           New Line Cinema
# 24                             WingNut Films
# 25                        Paramount Pictures
# 26                         Studio Babelsberg
# 27                        Universal Pictures
# 28                         Universal Studios
# 29                         Columbia Pictures
#                         ...
# 4773                           Miramax Films
# 4774                        Strand Releasing
# 4775                                     NaN
# 4776        Alliance Atlantis Communications
# 4777                                     NaN
# 4778    Boll Kino Beteiligungs GmbH & Co. KG
# 4779                                     NaN
# 4780                                     NaN
# 4781                                     NaN
# 4782                                     NaN
# 4783                          GO Productions
# 4784                                     NaN
# 4785                                     NaN
# 4786                                     NaN
# 4787                               Grindfest
# 4788                   Dreamland Productions
# 4789                                     NaN
# 4790           Jafar Panahi Film Productions
# 4791                              Park Films
# 4792                           Daiei Studios
# 4793                        Iconoclast Films
# 4794                         Gold Lion Films
# 4795                            Asylum Films
# 4796                               Thinkfilm
# 4797                                     NaN
# 4798                       Columbia Pictures
# 4799                                     NaN
# 4800                   Front Street Pictures
# 4801                                     NaN
# 4802                rusty bear entertainment
# Name: production_companies, Length: 4803, dtype: object

# %%
# creating a subset from larger dataset
df_movie_small = df_movie[['year','production_companies','revenue']]

# %%
# Find out the maximum revnue generating production company from each year
df_new = df_movie_small.ix[df_movie_small.groupby(['year']).revenue.idxmax()]
# Out:
# C:\Users\pierc\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df_new
# Out:
#       year                    production_companies     revenue
# 4553     0                                     NaN           0
# 4592  1916               Triangle Film Corporation     8394751
# 4661  1925               Metro-Goldwyn-Mayer (MGM)    22000000
# 2638  1927                      Paramount Pictures      650422
# 4594  1929               Metro-Goldwyn-Mayer (MGM)     4358000
# 3804  1930                       The Caddo Company     8000000
# 3611  1932                      Paramount Pictures          25
# 4570  1933                            Warner Bros.     2281000
# 4604  1934           Columbia Pictures Corporation     4500000
# 4495  1935                      RKO Radio Pictures     3202000
# 4238  1936                          United Artists     8500000
# 4259  1937                 Walt Disney Productions   184925486
# 4200  1938                       Columbia Pictures     7433101
# 3813  1939         Selznick International Pictures   400176459
# 1108  1940                      RKO Radio Pictures    84300000
# 4288  1941  Twentieth Century Fox Film Corporation     6000000
# 4441  1942                 Walt Disney Productions   267447150
# 4043  1944               Metro-Goldwyn-Mayer (MGM)     6892000
# 4283  1945                               Paramount    11000000
# 4062  1946                  Samuel Goldwyn Company    23650000
# 4091  1947  Twentieth Century Fox Film Corporation     7800000
# 3916  1948                          United Artists     9012000
# 4351  1949                   Republic Pictures (I)     7800000
# 3816  1950               Metro-Goldwyn-Mayer (MGM)     8000000
# 3229  1951               Metro-Goldwyn-Mayer (MGM)    30000000
# 3740  1952                      Paramount Pictures    36000000
# 3564  1953  Twentieth Century Fox Film Corporation    36000000
# 3568  1954                 Walt Disney Productions    28200000
# 4297  1955                      Paramount Pictures     7000000
# 3747  1956                      Joanna Productions    14400000
# ...    ...                                     ...         ...
# 1812  1988                          United Artists   412800000
# 1006  1989                               Lucasfilm   474171806
# 2017  1990                      Paramount Pictures   505000000
# 279   1991                Lightstorm Entertainment   520000000
# 1695  1992                    Walt Disney Pictures   504050219
# 675   1993                      Universal Pictures   920100000
# 494   1994                    Walt Disney Pictures   788241776
# 1541  1995                 Pixar Animation Studios   373554033
# 507   1996  Twentieth Century Fox Film Corporation   816969268
# 25    1997                      Paramount Pictures  1845034188
# 149   1998                 Jerry Bruckheimer Films   553799566
# 233   1999                               Lucasfilm   924317558
# 213   2000                      Paramount Pictures   546388105
# 197   2001                           1492 Pictures   976475550
# 330   2002                           WingNut Films   926287400
# 329   2003                           WingNut Films  1118888979
# 565   2004                          DreamWorks SKG   919838758
# 114   2005          Patalex IV Productions Limited   895921036
# 12    2006                    Walt Disney Pictures  1065659812
# 1     2007                    Walt Disney Pictures   961000000
# 65    2008                               DC Comics  1004558444
# 0     2009                 Ingenious Film Partners  2787965087
# 42    2010                    Walt Disney Pictures  1066969703
# 52    2011                      Paramount Pictures  1123746996
# 16    2012                      Paramount Pictures  1519557910
# 124   2013                    Walt Disney Pictures  1274219009
# 36    2014                      Paramount Pictures  1091405097
# 28    2015                       Universal Studios  1513528810
# 26    2016                       Studio Babelsberg  1153304495
# 4255  2017                                     NaN           0
#
# [91 rows x 3 columns]

# %%
# Count of years in which production company has generated maximum revennue
df_new = df_new.groupby('production_companies').year.count()
# Out:
# production_companies
# 1492 Pictures                              1
# Avon Production                            1
# Columbia Pictures                          1
# Columbia Pictures Corporation              3
# Crossbow Productions                       1
# DC Comics                                  1
# DreamWorks SKG                             1
# Eon Productions                            1
# Horizon Pictures (II)                      1
# Ingenious Film Partners                    1
# Jerry Bruckheimer Films                    1
# Joanna Productions                         1
# Lightstorm Entertainment                   1
# Lucasfilm                                  7
# Metro-Goldwyn-Mayer (MGM)                  5
# Paramount                                  1
# Paramount Pictures                        14
# Patalex IV Productions Limited             1
# Pixar Animation Studios                    1
# RKO Radio Pictures                         2
# Republic Pictures (I)                      1
# Samuel Goldwyn Company                     1
# Selznick International Pictures            1
# Stanley Kubrick Productions                1
# Studio Babelsberg                          1
# The Caddo Company                          1
# The Mirisch Corporation                    1
# Triangle Film Corporation                  1
# Twentieth Century Fox Film Corporation     7
# United Artists                             9
# Universal Pictures                         4
# Universal Studios                          1
# Walt Disney Pictures                       6
# Walt Disney Productions                    3
# Warner Bros.                               3
# WingNut Films                              2
# Name: year, dtype: int64

# %%
# To visualise we have taken where production company has highest grosser more than 1 year
df_new = df_new[df_new > 1]
df_new
# Out:
# production_companies
# Columbia Pictures Corporation              3
# Lucasfilm                                  7
# Metro-Goldwyn-Mayer (MGM)                  5
# Paramount Pictures                        14
# RKO Radio Pictures                         2
# Twentieth Century Fox Film Corporation     7
# United Artists                             9
# Universal Pictures                         4
# Walt Disney Pictures                       6
# Walt Disney Productions                    3
# Warner Bros.                               3
# WingNut Films                              2
# Name: year, dtype: int64

# %%
df_new.plot(kind='bar', stacked=True, colormap='autumn')

# %% [markdown]
# QUES3: Which movie has given maximum hit for each year?
#
# CONCLUSIONS:Paramount pictures has been 14 times highest revenue earning production comapny of each year followed by United Artist
#
#                                   **QUES3 ENDS**

# %%
# Now we look into credits dataset to analyse some pattern
df_credit
# Out:
#       movie_id                                        title  \
# 0        19995                                       Avatar
# 1          285     Pirates of the Caribbean: At World's End
# 2       206647                                      Spectre
# 3        49026                        The Dark Knight Rises
# 4        49529                                  John Carter
# 5          559                                 Spider-Man 3
# 6        38757                                      Tangled
# 7        99861                      Avengers: Age of Ultron
# 8          767       Harry Potter and the Half-Blood Prince
# 9       209112           Batman v Superman: Dawn of Justice
# 10        1452                             Superman Returns
# 11       10764                            Quantum of Solace
# 12          58   Pirates of the Caribbean: Dead Man's Chest
# 13       57201                              The Lone Ranger
# 14       49521                                 Man of Steel
# 15        2454     The Chronicles of Narnia: Prince Caspian
# 16       24428                                 The Avengers
# 17        1865  Pirates of the Caribbean: On Stranger Tides
# 18       41154                               Men in Black 3
# 19      122917    The Hobbit: The Battle of the Five Armies
# 20        1930                       The Amazing Spider-Man
# 21       20662                                   Robin Hood
# 22       57158          The Hobbit: The Desolation of Smaug
# 23        2268                           The Golden Compass
# 24         254                                    King Kong
# 25         597                                      Titanic
# 26      271110                   Captain America: Civil War
# 27       44833                                   Battleship
# 28      135397                               Jurassic World
# 29       37724                                      Skyfall
# ...        ...                                          ...
# 4773      2292                                       Clerks
# 4774     42497                               Pink Narcissus
# 4775     33693                                  Funny Ha Ha
# 4776     14585                        In the Company of Men
# 4777    185465                                       Manito
# 4778     38780                                      Rampage
# 4779     14022                                      Slacker
# 4780    366967                                  Dutch Kills
# 4781    255266                                    Dry Spell
# 4782     17345                                     Flywheel
# 4783    226458                                     Backmask
# 4784     24055                              The Puffy Chair
# 4785    287625                         Stories of Our Lives
# 4786     44990                             Breaking Upwards
# 4787     86304                     All Superheroes Must Die
# 4788       692                               Pink Flamingos
# 4789     39851                                        Clean
# 4790     13898                                   The Circle
# 4791    157185                                  Tin Can Man
# 4792     36095                                         Cure
# 4793    182291                               On The Downlow
# 4794    286939                 Sanctuary: Quite a Conundrum
# 4795    124606                                         Bang
# 4796     14337                                       Primer
# 4797     67238                                       Cavite
# 4798      9367                                  El Mariachi
# 4799     72766                                    Newlyweds
# 4800    231617                    Signed, Sealed, Delivered
# 4801    126186                             Shanghai Calling
# 4802     25975                            My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# 5     [{"cast_id": 30, "character": "Peter Parker / ...
# 6     [{"cast_id": 34, "character": "Flynn Rider (vo...
# 7     [{"cast_id": 76, "character": "Tony Stark / Ir...
# 8     [{"cast_id": 3, "character": "Harry Potter", "...
# 9     [{"cast_id": 18, "character": "Bruce Wayne / B...
# 10    [{"cast_id": 3, "character": "Superman / Clark...
# 11    [{"cast_id": 1, "character": "James Bond", "cr...
# 12    [{"cast_id": 37, "character": "Captain Jack Sp...
# 13    [{"cast_id": 4, "character": "Tonto", "credit_...
# 14    [{"cast_id": 2, "character": "Clark Kent / Kal...
# 15    [{"cast_id": 1, "character": "Prince Caspian",...
# 16    [{"cast_id": 46, "character": "Tony Stark / Ir...
# 17    [{"cast_id": 15, "character": "Captain Jack Sp...
# 18    [{"cast_id": 4, "character": "Agent J", "credi...
# 19    [{"cast_id": 10, "character": "Bilbo Baggins",...
# 20    [{"cast_id": 56, "character": "Peter Parker / ...
# 21    [{"cast_id": 1, "character": "Robin Longstride...
# 22    [{"cast_id": 3, "character": "Bilbo Baggins", ...
# 23    [{"cast_id": 43, "character": "Lyra Belacqua",...
# 24    [{"cast_id": 5, "character": "Ann Darrow", "cr...
# 25    [{"cast_id": 20, "character": "Rose DeWitt Buk...
# 26    [{"cast_id": 9, "character": "Steve Rogers / C...
# 27    [{"cast_id": 3, "character": "Lieutenant Alex ...
# 28    [{"cast_id": 10, "character": "Owen Grady", "c...
# 29    [{"cast_id": 1, "character": "James Bond", "cr...
# ...                                                 ...
# 4773  [{"cast_id": 7, "character": "Dante Hicks", "c...
# 4774  [{"cast_id": 1006, "character": "Pan", "credit...
# 4775  [{"cast_id": 1, "character": "Marnie", "credit...
# 4776  [{"cast_id": 1, "character": "Chad", "credit_i...
# 4777  [{"cast_id": 1, "character": "Junior Moreno", ...
# 4778  [{"cast_id": 1, "character": "Bill Williamson"...
# 4779  [{"cast_id": 1, "character": "Should Have Stay...
# 4780  [{"cast_id": 4, "character": "Val", "credit_id...
# 4781  [{"cast_id": 4, "character": "Sasha", "credit_...
# 4782  [{"cast_id": 1, "character": "Jay", "credit_id...
# 4783  [{"cast_id": 3, "character": "Father Conway", ...
# 4784  [{"cast_id": 4, "character": "Josh", "credit_i...
# 4785  [{"cast_id": 8, "character": "", "credit_id": ...
# 4786  [{"cast_id": 1, "character": "Zoe", "credit_id...
# 4787  [{"cast_id": 1, "character": "Charge / John", ...
# 4788  [{"cast_id": 8, "character": "Divine / Babs Jo...
# 4789  [{"cast_id": 1, "character": "Emily Wang", "cr...
# 4790  [{"cast_id": 3, "character": "Nargess", "credi...
# 4791  [{"cast_id": 1, "character": "Dave", "credit_i...
# 4792  [{"cast_id": 3, "character": "Kenichi Takabe",...
# 4793  [{"cast_id": 1, "character": "Isaac", "credit_...
# 4794  [{"cast_id": 3, "character": "Mimi", "credit_i...
# 4795  [{"cast_id": 2, "character": "The Girl", "cred...
# 4796  [{"cast_id": 1, "character": "Aaron", "credit_...
# 4797                                                 []
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# 5     [{"credit_id": "52fe4252c3a36847f80151a5", "de...
# 6     [{"credit_id": "52fe46db9251416c91062101", "de...
# 7     [{"credit_id": "55d5f7d4c3a3683e7e0016eb", "de...
# 8     [{"credit_id": "52fe4273c3a36847f801fab1", "de...
# 9     [{"credit_id": "553bf23692514135c8002886", "de...
# 10    [{"credit_id": "553bef6a9251416874003c8f", "de...
# 11    [{"credit_id": "52fe43b29251416c7501aa63", "de...
# 12    [{"credit_id": "52fe4211c3a36847f8001873", "de...
# 13    [{"credit_id": "52fe4928c3a36847f818be95", "de...
# 14    [{"credit_id": "52fe4799c3a36847f813e667", "de...
# 15    [{"credit_id": "55a239e69251412979002e8b", "de...
# 16    [{"credit_id": "52fe4495c3a368484e02b1cf", "de...
# 17    [{"credit_id": "566b4f54c3a3683f56005151", "de...
# 18    [{"credit_id": "52fe45b7c3a36847f80d68c7", "de...
# 19    [{"credit_id": "548ad49a9251414fa20011ab", "de...
# 20    [{"credit_id": "5395a60dc3a368641d004492", "de...
# 21    [{"credit_id": "52fe43f2c3a368484e0076ad", "de...
# 22    [{"credit_id": "52fe4926c3a36847f818b787", "de...
# 23    [{"credit_id": "52fe4348c3a36847f8048635", "de...
# 24    [{"credit_id": "52fe422ec3a36847f800a1d7", "de...
# 25    [{"credit_id": "52fe425ac3a36847f8017985", "de...
# 26    [{"credit_id": "569443d59251414b67000428", "de...
# 27    [{"credit_id": "52fe469ec3a36847f8108d45", "de...
# 28    [{"credit_id": "52fe4bf7c3a368484e1a0683", "de...
# 29    [{"credit_id": "52fe46689251416c910537ad", "de...
# ...                                                 ...
# 4773  [{"credit_id": "52fe434ac3a36847f8049253", "de...
# 4774  [{"credit_id": "52fe4606c3a36847f80e7ed9", "de...
# 4775  [{"credit_id": "52fe45309251416c9102a535", "de...
# 4776  [{"credit_id": "52fe46049251416c7506a36b", "de...
# 4777  [{"credit_id": "54931bbf925141090e001d32", "de...
# 4778  [{"credit_id": "52fe46df9251416c91062979", "de...
# 4779  [{"credit_id": "52fe45c49251416c75061c17", "de...
# 4780  [{"credit_id": "563d13ec9251414c70007d5e", "de...
# 4781  [{"credit_id": "52fe4ee39251416c911412e7", "de...
# 4782  [{"credit_id": "52fe471e9251416c7508e579", "de...
# 4783  [{"credit_id": "554c8351c3a3685e500041f5", "de...
# 4784  [{"credit_id": "52fe447fc3a368484e026881", "de...
# 4785  [{"credit_id": "549e790a9251414d27003096", "de...
# 4786  [{"credit_id": "572239efc3a368712a0007db", "de...
# 4787  [{"credit_id": "52fe497f9251416c910af3d1", "de...
# 4788  [{"credit_id": "52fe426bc3a36847f801d203", "de...
# 4789  [{"credit_id": "52fe47369251416c9106db9b", "de...
# 4790  [{"credit_id": "52fe45b09251416c7505f189", "de...
# 4791  [{"credit_id": "54c7851b925141679100372a", "de...
# 4792  [{"credit_id": "52fe45cc9251416c9103eb7b", "de...
# 4793  [{"credit_id": "548c416392514122ef00197d", "de...
# 4794  [{"credit_id": "545f8107c3a3686cbb0041fd", "de...
# 4795  [{"credit_id": "52fe4ab0c3a368484e161add", "de...
# 4796  [{"credit_id": "52fe45e79251416c75066791", "de...
# 4797  [{"credit_id": "52fe475dc3a368484e0c319f", "de...
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4803 rows x 4 columns]

# %%
# To start with we have to clean the dataset first, in particular cast column
df_credit['cast'] = df_credit['cast'].str.split(":",n=6,expand=True)[6]
df_credit['cast'] = df_credit['cast'].str.split(",",n=0,expand=True)[0]
df_credit['cast']
# Out:
# 0             "Sam Worthington"
# 1                 "Johnny Depp"
# 2                "Daniel Craig"
# 3              "Christian Bale"
# 4               "Taylor Kitsch"
# 5               "Tobey Maguire"
# 6                "Zachary Levi"
# 7           "Robert Downey Jr."
# 8            "Daniel Radcliffe"
# 9                 "Ben Affleck"
# 10              "Brandon Routh"
# 11               "Daniel Craig"
# 12                "Johnny Depp"
# 13                "Johnny Depp"
# 14               "Henry Cavill"
# 15                 "Ben Barnes"
# 16          "Robert Downey Jr."
# 17                "Johnny Depp"
# 18                 "Will Smith"
# 19             "Martin Freeman"
# 20            "Andrew Garfield"
# 21              "Russell Crowe"
# 22             "Martin Freeman"
# 23       "Dakota Blue Richards"
# 24                "Naomi Watts"
# 25               "Kate Winslet"
# 26                "Chris Evans"
# 27              "Taylor Kitsch"
# 28                "Chris Pratt"
# 29               "Daniel Craig"
#                  ...
# 4773         "Brian O'Halloran"
# 4774            "Bobby Kendall"
# 4775         "Kate Dollenmayer"
# 4776            "Aaron Eckhart"
# 4777                 "Franky G"
# 4778         "Brendan Fletcher"
# 4779        "Richard Linklater"
# 4780                "R.L. Mann"
# 4781            "Suzi Lorraine"
# 4782            "Alex Kendrick"
# 4783             "Stephen Lang"
# 4784             "Mark Duplass"
# 4785             "Louis Brooke"
# 4786         "Zoe Lister-Jones"
# 4787              "Jason Trost"
# 4788                   "Divine"
# 4789            "Maggie Cheung"
# 4790        "Nargess Mamizadeh"
# 4791            "Michael Parle"
# 4792             "Koji Yakusho"
# 4793              "Tony Sancho"
# 4794              "Sasha Ramos"
# 4795           "Darling Narita"
# 4796            "Shane Carruth"
# 4797                       None
# 4798          "Carlos Gallardo"
# 4799             "Edward Burns"
# 4800              "Eric Mabius"
# 4801            "Daniel Henney"
# 4802           "Drew Barrymore"
# Name: cast, Length: 4803, dtype: object

# %%
df_credit['cast'] =  df_credit['cast'].str.replace('"', '')
df_credit['cast'] = df_credit['cast'].str.strip()

# %%
# Merge both the credit and movie dataset
df_combined = df_credit.merge(df_movie, left_on='movie_id', right_on='id', how='inner')

# %%
df_cast = df_combined[['cast','year','revenue']]

# %%
df_cast = df_cast.ix[df_cast.groupby(['year']).revenue.idxmax()]
# Out:
# C:\Users\pierc\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df_cast
# Out:
#                         cast  year     revenue
# 4553                    None     0           0
# 4592            Lillian Gish  1916     8394751
# 4661            John Gilbert  1925    22000000
# 2638           Brigitte Helm  1927      650422
# 4594            Charles King  1929     4358000
# 3804                Ben Lyon  1930     8000000
# 3611             Helen Hayes  1932          25
# 4570           Warner Baxter  1933     2281000
# 4604             Clark Gable  1934     4500000
# 4495            Fred Astaire  1935     3202000
# 4238         Charlie Chaplin  1936     8500000
# 4259       Adriana Caselotti  1937   184925486
# 4200             Jean Arthur  1938     7433101
# 3813            Vivien Leigh  1939   400176459
# 1108               Mel Blanc  1940    84300000
# 4288          Walter Pidgeon  1941     6000000
# 4441          Donnie Dunagan  1942   267447150
# 4043             Red Skelton  1944     6892000
# 4283             Ray Milland  1945    11000000
# 4062           Fredric March  1946    23650000
# 4091            Gregory Peck  1947     7800000
# 3916              John Wayne  1948     9012000
# 4351              John Wayne  1949     7800000
# 3816            Betty Hutton  1950     8000000
# 3229           Robert Taylor  1951    30000000
# 3740            Betty Hutton  1952    36000000
# 3564          Richard Burton  1953    36000000
# 3568            Kirk Douglas  1954    28200000
# 4297            Edmund Gwenn  1955     7000000
# 3747          Burt Lancaster  1956    14400000
# ...                      ...   ...         ...
# 1812          Dustin Hoffman  1988   412800000
# 1006           Harrison Ford  1989   474171806
# 2017          Patrick Swayze  1990   505000000
# 279    Arnold Schwarzenegger  1991   520000000
# 1695           Scott Weinger  1992   504050219
# 675                Sam Neill  1993   920100000
# 494   Jonathan Taylor Thomas  1994   788241776
# 1541               Tom Hanks  1995   373554033
# 507               Will Smith  1996   816969268
# 25              Kate Winslet  1997  1845034188
# 149             Bruce Willis  1998   553799566
# 233              Liam Neeson  1999   924317558
# 213               Tom Cruise  2000   546388105
# 197         Daniel Radcliffe  2001   976475550
# 330              Elijah Wood  2002   926287400
# 329              Elijah Wood  2003  1118888979
# 565               Mike Myers  2004   919838758
# 114         Daniel Radcliffe  2005   895921036
# 12               Johnny Depp  2006  1065659812
# 1                Johnny Depp  2007   961000000
# 65            Christian Bale  2008  1004558444
# 0            Sam Worthington  2009  2787965087
# 42                 Tom Hanks  2010  1066969703
# 52              Shia LaBeouf  2011  1123746996
# 16         Robert Downey Jr.  2012  1519557910
# 124             Kristen Bell  2013  1274219009
# 36             Mark Wahlberg  2014  1091405097
# 28               Chris Pratt  2015  1513528810
# 26               Chris Evans  2016  1153304495
# 4255            Roni Akurati  2017           0
#
# [91 rows x 3 columns]

# %%
df_cast = df_cast.groupby('cast').year.count()
df_cast  = df_cast [df_cast >1]
df_cast
# Out:
# cast
# Betty Hutton        2
# Daniel Radcliffe    2
# Elijah Wood         2
# Harrison Ford       3
# John Wayne          2
# Johnny Depp         2
# Mark Hamill         3
# Sean Connery        4
# Tom Cruise          2
# Tom Hanks           2
# Name: year, dtype: int64

# %%
df_cast.plot(kind='bar', stacked=True, colormap='autumn')

# %% [markdown]
# Ques4 : Which actor has given maximum hit in each year ?
# CONCLUSION : Sean Connery has given maximum hit each year.
